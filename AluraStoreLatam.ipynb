# %% [markdown]
# # Importación de datos

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url1)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %%
tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %%
#Mostrando la cantidad de filas y columnas de cada del dataset de cada tienda
print("La cantidad de filas de columnas de la tienda1 es:", tienda1.shape)
print("La cantidad de filas de columnas de la tienda2 es:", tienda2.shape)
print("La cantidad de filas de columnas de la tienda3 es:", tienda3.shape)
print("La cantidad de filas de columnas de la tienda4 es:", tienda4.shape)
# Out:
# La cantidad de filas de columnas de la tienda1 es: (2359, 12)
# La cantidad de filas de columnas de la tienda2 es: (2359, 12)
# La cantidad de filas de columnas de la tienda3 es: (2359, 12)
# La cantidad de filas de columnas de la tienda4 es: (2358, 12)

# %%
print(f"Las columnas del dataset de la tienda 1 es: \n", tienda1.columns)
print("Las columnas del dataset de la tienda 2 es: \n", tienda2.columns)
print("Las columnas del dataset de la tienda 3 es: \n", tienda3.columns)
print("Las columnas del dataset de la tienda 4 es: \n", tienda4.columns)
# Out:
# Las columnas del dataset de la tienda 1 es:
#  Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')
# Las columnas del dataset de la tienda 2 es:
#  Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')
# Las columnas del dataset de la tienda 3 es:
#  Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')
# Las columnas del dataset de la tienda 4 es:
#  Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
# ...

# %%
#Mostrando el tipo de dato de los datos de las columnas
print("LOS TIPOS DE DATOS DE LAS COLUMNAS DEL DATASET DE LA TIENDA 1\n",tienda1.dtypes)
print("")
print("LOS TIPOS DE DATOS DE LAS COLUMNAS DEL DATASET DE LA TIENDA 2\n",tienda2.dtypes)
print("")
print("LOS TIPOS DE DATOS DE LAS COLUMNAS DEL DATASET DE LA TIENDA 3\n",tienda3.dtypes)
print("")
print("LOS TIPOS DE DATOS DE LAS COLUMNAS DEL DATASET DE LA TIENDA 4\n",tienda4.dtypes)
# Out:
# LOS TIPOS DE DATOS DE LAS COLUMNAS DEL DATASET DE LA TIENDA 1
#  Producto                   object
# Categoría del Producto     object
# Precio                    float64
# Costo de envío            float64
# Fecha de Compra            object
# Vendedor                   object
# Lugar de Compra            object
# Calificación                int64
# Método de pago             object
# Cantidad de cuotas          int64
# lat                       float64
# lon                       float64
# dtype: object
#
# LOS TIPOS DE DATOS DE LAS COLUMNAS DEL DATASET DE LA TIENDA 2
#  Producto                   object
# Categoría del Producto     object
# Precio                    float64
# Costo de envío            float64
# Fecha de Compra            object
# Vendedor                   object
# Lugar de Compra            object
# Calificación                int64
# Método de pago             object
# Cantidad de cuotas          int64
# lat                       float64
# ...

# %%
#Mostrando información estadistica de cada tienda
print("Información estadística de la tienda 1: ")
tienda1.describe(include="all")
# Out:
# Información estadística de la tienda 1:
#           Producto Categoría del Producto        Precio  Costo de envío  \
# count         2359                   2359  2.359000e+03     2359.000000
# unique          51                      8           NaN             NaN
# top     Microondas                Muebles           NaN             NaN
# freq            60                    465           NaN             NaN
# mean           NaN                    NaN  4.878679e+05    26018.609580
# std            NaN                    NaN  6.146868e+05    32860.001783
# min            NaN                    NaN  7.600000e+03        0.000000
# 25%            NaN                    NaN  5.575000e+04     3100.000000
# 50%            NaN                    NaN  2.353000e+05    12400.000000
# 75%            NaN                    NaN  6.781000e+05    36000.000000
# max            NaN                    NaN  2.977000e+06   160800.000000
#
# ...

# %%
print("Información estadística de la tienda 2: ")
tienda2.describe(include="all")
# Out:
# Información estadística de la tienda 2:
#                          Producto Categoría del Producto        Precio  \
# count                        2359                   2359  2.359000e+03
# unique                         51                      8           NaN
# top     Iniciando en programación                Muebles           NaN
# freq                           65                    442           NaN
# mean                          NaN                    NaN  4.732274e+05
# std                           NaN                    NaN  5.955595e+05
# min                           NaN                    NaN  7.600000e+03
# 25%                           NaN                    NaN  5.455000e+04
# 50%                           NaN                    NaN  2.182000e+05
# 75%                           NaN                    NaN  6.777000e+05
# max                           NaN                    NaN  2.953400e+06
#
#         Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# ...

# %%
print("Información estadística de la tienda 3: ")
tienda3.describe(include="all")
# Out:
# Información estadística de la tienda 3:
#              Producto Categoría del Producto        Precio  Costo de envío  \
# count            2359                   2359  2.359000e+03     2359.000000
# unique             51                      8           NaN             NaN
# top     Kit de bancas                Muebles           NaN             NaN
# freq               57                    499           NaN             NaN
# mean              NaN                    NaN  4.654598e+05    24805.680373
# std               NaN                    NaN  5.806434e+05    30945.889626
# min               NaN                    NaN  7.600000e+03        0.000000
# 25%               NaN                    NaN  5.740000e+04     3100.000000
# 50%               NaN                    NaN  2.263000e+05    11900.000000
# 75%               NaN                    NaN  6.660500e+05    34950.000000
# max               NaN                    NaN  2.968200e+06   158400.000000
#
# ...

# %%
print("Información estadística de la tienda 4: ")
tienda4.describe(include="all")
# Out:
# Información estadística de la tienda 4:
#         Producto Categoría del Producto        Precio  Costo de envío  \
# count       2358                   2358  2.358000e+03     2358.000000
# unique        51                      8           NaN             NaN
# top     Cama box                Muebles           NaN             NaN
# freq          62                    480           NaN             NaN
# mean         NaN                    NaN  4.403629e+05    23459.457167
# std          NaN                    NaN  5.687556e+05    30279.100836
# min          NaN                    NaN  7.600000e+03        0.000000
# 25%          NaN                    NaN  5.340000e+04     2900.000000
# 50%          NaN                    NaN  2.094500e+05    10950.000000
# 75%          NaN                    NaN  6.342250e+05    33300.000000
# max          NaN                    NaN  2.902200e+06   154700.000000
#
#        Fecha de Compra       Vendedor Lugar de Compra  Calificación  \
# ...

# %%
#Encontrando datos nulos
print("Mostrando cantidad de datos nulos de la tienda 1")
tienda1.isnull().sum()
# Out:
# Mostrando cantidad de datos nulos de la tienda 1
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
print("Mostrando cantidad de datos nulos de la tienda 2")
tienda2.isnull().sum()
# Out:
# Mostrando cantidad de datos nulos de la tienda 2
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
print("Mostrando cantidad de datos nulos de la tienda 3")
tienda3.isnull().sum()
# Out:
# Mostrando cantidad de datos nulos de la tienda 3
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
print("Mostrando cantidad de datos nulos de la tienda 4")
tienda4.isnull().sum()
# Out:
# Mostrando cantidad de datos nulos de la tienda 4
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calcular ingresos por tienda
ingreso_tienda1 = tienda1["Precio"].sum()
ingreso_tienda2 = tienda2["Precio"].sum()
ingreso_tienda3 = tienda3["Precio"].sum()
ingreso_tienda4 = tienda4["Precio"].sum()

# %%
#Mostrando ingreso total de cada tienda
print("El ingreso total de la tienda 1 es: ",ingreso_tienda1)
print("El ingreso total de la tienda 2 es: ",ingreso_tienda2)
print("El ingreso total de la tienda 3 es: ",ingreso_tienda3)
print("El ingreso total de la tienda 4 es: ",ingreso_tienda4)
# Out:
# El ingreso total de la tienda 1 es:  1150880400.0
# El ingreso total de la tienda 2 es:  1116343500.0
# El ingreso total de la tienda 3 es:  1098019600.0
# El ingreso total de la tienda 4 es:  1038375700.0

# %%
# Gráfico de barras: Ingresos por tienda
ingresos = [ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4]
tiendas = ["tienda 1", "tienda 2", "tienda 3", "tienda 4"]

plt.figure(figsize=(5,3))
plt.bar(tiendas, ingresos, color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
plt.title("Ingresos por tienda")
plt.xlabel("Tiendas")
plt.ylabel("Ingresos totales")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Cantidad de productos vendidos por categoría en cada tienda

ventas_categoria_t1 = tienda1.groupby("Categoría del Producto")["Producto"].count()
ventas_categoria_t2 = tienda2.groupby("Categoría del Producto")["Producto"].count()
ventas_categoria_t3 = tienda3.groupby("Categoría del Producto")["Producto"].count()
ventas_categoria_t4 = tienda4.groupby("Categoría del Producto")["Producto"].count()

# %%
print("Tienda 1 - Ventas por categoría")
display(ventas_categoria_t1.sort_values(ascending=False))

print("Tienda 2 - Ventas por categoría")
display(ventas_categoria_t2.sort_values(ascending=False))

print("Tienda 3 - Ventas por categoría")
display(ventas_categoria_t3.sort_values(ascending=False))

print("Tienda 4 - Ventas por categoría")
display(ventas_categoria_t4.sort_values(ascending=False))
# Out:
# Tienda 1 - Ventas por categoría
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Producto, dtype: int64
# Tienda 2 - Ventas por categoría
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Producto, dtype: int64
# Tienda 3 - Ventas por categoría
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# ...

# %%
import numpy as np
ventas_por_categoria = pd.DataFrame({
    'Tienda 1': ventas_categoria_t1,
    'Tienda 2': ventas_categoria_t2,
    'Tienda 3': ventas_categoria_t3,
    'Tienda 4': ventas_categoria_t4
})

# Usar un estilo de Matplotlib para mejorar la estética
plt.style.use('seaborn-v0_8-darkgrid')

fig, ax = plt.subplots(figsize=(8, 5))

categories = ventas_por_categoria.index
bar_width = 0.2

# Definir posiciones para las barras agrupadas
r1 = np.arange(len(categories))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Crear las barras para cada tienda
ax.bar(r1, ventas_por_categoria['Tienda 1'], color='skyblue', width=bar_width, edgecolor='white', label='Tienda 1')
ax.bar(r2, ventas_por_categoria['Tienda 2'], color='lightcoral', width=bar_width, edgecolor='white', label='Tienda 2')
ax.bar(r3, ventas_por_categoria['Tienda 3'], color='lightgreen', width=bar_width, edgecolor='white', label='Tienda 3')
ax.bar(r4, ventas_por_categoria['Tienda 4'], color='gold', width=bar_width, edgecolor='white', label='Tienda 4')

# Añadir etiquetas, título y leyenda
ax.set_xlabel('Categoría del Producto', fontsize=12)
ax.set_ylabel('Cantidad Vendida', fontsize=12)
ax.set_title('Ventas por Categoría en Todas las Tiendas', fontsize=16)
ax.set_xticks([r + 1.5 * bar_width for r in range(len(categories))])
ax.set_xticklabels(categories, rotation=45, ha='right')
ax.legend(title='Tienda', bbox_to_anchor=(1.05, 1), loc='upper left')

# Asegurar que las líneas de los ejes sean visibles y más prominentes
ax.spines['top'].set_visible(False) # Ocultar el eje superior
ax.spines['right'].set_visible(False) # Ocultar el eje derecho
ax.spines['left'].set_linewidth(1.5) # Hacer el eje izquierdo más grueso
ax.spines['bottom'].set_linewidth(1.5) # Hacer el eje inferior más grueso
ax.spines['left'].set_color('black') # Color del eje izquierdo
ax.spines['bottom'].set_color('black') # Color del eje inferior

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calificación promedio de cada tienda

promedio_t1 = tienda1["Calificación"].mean()
promedio_t2 = tienda2["Calificación"].mean()
promedio_t3 = tienda3["Calificación"].mean()
promedio_t4 = tienda4["Calificación"].mean()

# %%
tienda1 ["Calificación"]
# Out:
# 0       4
# 1       1
# 2       1
# 3       4
# 4       5
#        ..
# 2354    1
# 2355    5
# 2356    5
# 2357    1
# 2358    4
# Name: Calificación, Length: 2359, dtype: int64

# %%
print("Calificación promedio de cada tienda:")
print(f"Tienda 1: {promedio_t1:.2f}")
print(f"Tienda 2: {promedio_t2:.2f}")
print(f"Tienda 3: {promedio_t3:.2f}")
print(f"Tienda 4: {promedio_t4:.2f}")
# Out:
# Calificación promedio de cada tienda:
# Tienda 1: 3.98
# Tienda 2: 4.04
# Tienda 3: 4.05
# Tienda 4: 4.00

# %%
#Grafico de calificacion promedio por tienda

calificaciones_promedio = [promedio_t1, promedio_t2, promedio_t3, promedio_t4]

fig, ax = plt.subplots(figsize=(5, 3))

ax.bar(tiendas, calificaciones_promedio, color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
ax.set_title('Calificación Promedio por Tienda', fontsize=15)
ax.set_xlabel('Tiendas', fontsize=10)
ax.set_ylabel('Calificación Promedio', fontsize=12)
ax.set_ylim(0, 5) # Las calificaciones van de 1 a 5

# Añadir el valor de la calificación en la parte superior de cada barra
for i, v in enumerate(calificaciones_promedio):
    ax.text(i, v + 0.1, f'{v:.2f}', ha='center', va='bottom', fontsize=10)

# Asegurar que las líneas de los ejes sean visibles y más prominentes
ax.spines['left'].set_linewidth(1.5) # Hacer el eje izquierdo más grueso
ax.spines['bottom'].set_linewidth(1.5) # Hacer el eje inferior más grueso
ax.spines['left'].set_color('black') # Color del eje izquierdo
ax.spines['bottom'].set_color('black') # Color del eje inferior

ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Conteo de ventas por producto en cada tienda

ventas_prod_t1 = tienda1["Producto"].value_counts()
ventas_prod_t2 = tienda2["Producto"].value_counts()
ventas_prod_t3 = tienda3["Producto"].value_counts()
ventas_prod_t4 = tienda4["Producto"].value_counts()

# %%
print("Tienda 1:")
print("Más vendidos:")
display(ventas_prod_t1.head(5))
print("Menos vendidos:")
display(ventas_prod_t1.tail(5))

print("\nTienda 2:")
print("Más vendidos:")
display(ventas_prod_t2.head(5))
print("Menos vendidos:")
display(ventas_prod_t2.tail(5))

print("\nTienda 3:")
print("Más vendidos:")
display(ventas_prod_t3.head(5))
print("Menos vendidos:")
display(ventas_prod_t3.tail(5))

print("\nTienda 4:")
print("Más vendidos:")
display(ventas_prod_t4.head(5))
print("Menos vendidos:")
display(ventas_prod_t4.tail(5))
# Out:
# Tienda 1:
# Más vendidos:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Menos vendidos:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
# Tienda 2:
# Más vendidos:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Menos vendidos:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64
# Tienda 3:
# Más vendidos:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Costo de envío promedio por tienda

envio_prom_t1 = tienda1["Costo de envío"].mean()
envio_prom_t2 = tienda2["Costo de envío"].mean()
envio_prom_t3 = tienda3["Costo de envío"].mean()
envio_prom_t4 = tienda4["Costo de envío"].mean()

# %%
print("Costo de envío promedio por tienda:")
print(f"Tienda 1: ${envio_prom_t1:.2f}")
print(f"Tienda 2: ${envio_prom_t2:.2f}")
print(f"Tienda 3: ${envio_prom_t3:.2f}")
print(f"Tienda 4: ${envio_prom_t4:.2f}")
# Out:
# Costo de envío promedio por tienda:
# Tienda 1: $26018.61
# Tienda 2: $25216.24
# Tienda 3: $24805.68
# Tienda 4: $23459.46

# %% [markdown]
# # Informe Final — Análisis de Tiendas Alura Store

# %% [markdown]
# ## 1. Introducción
# El propósito de este análisis es determinar cuál de las cuatro tiendas de la cadena **Alura Store** debería vender el Sr. Juan, considerando métricas clave de desempeño: **ingresos**, **ventas por categoría**, **calificación promedio de los clientes**, **productos más/menos vendidos** y **costo de envío promedio**.
# El análisis se realizó a partir de los cuatro archivos proporcionados, uno por tienda, integrando y comparando sus resultados.

# %% [markdown]
# ## 2. Metodología
# - Se cargaron los 4 archivos de las tiendas.
# - Se calcularon métricas por tienda:
#   - Ingreso total.
#   - Número de ventas.
#   - Ingreso promedio por venta.
#   - Calificación promedio.
#   - Costo de envío promedio.
#   - Categorías más y menos vendidas.
#   - Productos más y menos vendidos.
# - Se generaron visualizaciones para respaldar los hallazgos.
#
# ---

# %% [markdown]
# ## 3. Resumen comparativo por tienda
#
# | Tienda    | Ingreso total     | Nº ventas | Ingreso por venta | Calificación promedio | Envío promedio |
# |-----------|-------------------:|----------:|------------------:|----------------------:|---------------:|
# | **Tienda 1** | 1,150,880,400.00 | 2359 | 487,867.91 | 3.98 | 26,018.61 |
# | **Tienda 2** | 1,116,343,500.00 | 2359 | 473,227.43 | 4.04 | 25,216.24 |
# | **Tienda 3** | 1,098,020,000.00 | 2359 | 465,459.77 | 4.05 | 24,805.68 |
# | **Tienda 4** | 1,038,375,700.00 | 2358 | 440,362.89 | 4.00 | 23,459.46 |
#
# ---

# %% [markdown]
# ### Grafico de ingreso total por tienda
#
# ![Ingreso total.png](data:image/png;base64,...)

# %% [markdown]
# ### Calificacion Promedio de las tiendas
#
# ![calificacion promedio.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Categorías más vendidas por tienda
# - **Tienda 1:** Muebles
# - **Tienda 2:** Muebles
# - **Tienda 3:** Muebles
# - **Tienda 4:** Muebles
#
# La categoría con mayor peso en ventas es consistente entre las tiendas.
#
# ---
# ![ventas categoria.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Productos más vendidos por tienda
# - **Tienda 1:** TV LED UHD 4K
# - **Tienda 2:** Iniciando en programación
# - **Tienda 3:** Kit de bancas
# - **Tienda 4:** Cama box
#
# ---

# %% [markdown]
# ## 6. Análisis de fortalezas y debilidades
#
# ### Tienda 1
# - **Fortalezas:** mayor ingreso total, mayor ingreso por venta.
# - **Debilidades:** costo de envío más alto y calificación un poco menor.
#
# ### Tienda 2
# - **Fortalezas:** equilibrio entre ventas, reputación y costos.
# - **Debilidades:** ingreso por venta inferior al de Tienda 1.
#
# ### Tienda 3
# - **Fortalezas:** mejor calificación promedio (4.05).
# - **Debilidades:** ingreso total ligeramente menor.
#
# ### Tienda 4
# - **Fortalezas:** menor costo de envío.
# - **Debilidades:** menor ingreso total y menor ingreso por venta de las cuatro.
#
# ---

# %% [markdown]
# ## 7. Conclusión — ¿Qué tienda debería vender el Sr. Juan?
#
# ###  **Recomendación: vender la *Tienda 4*.**
#
# **Razones principales:**
#
# 1. **Es la de menor ingreso total.**
# 2. **Es la de menor ingreso promedio por venta**, a pesar de tener casi el mismo número de transacciones que las demás.
# 3. **No destaca en calificación**, ya que su puntaje es intermedio (4.00).
# 4. Su menor costo de envío no compensa su menor rentabilidad global.
# 5. Al venderla, se libera capital sin afectar de manera desproporcionada el rendimiento general de la cadena.
#
# En conjunto, la Tienda 4 presenta la **mayor debilidad relativa** en términos de ingresos, ticket promedio y margen potencial.
#
# ---
